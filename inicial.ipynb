# %% [markdown]
# # Projeto Python IA: Inteligência Artificial e Previsões
#
# ### Case: Score de Crédito dos Clientes
#
# Você foi contratado por um banco para conseguir definir o score de crédito dos clientes. Você precisa analisar todos os clientes do banco e, com base nessa análise, criar um modelo que consiga ler as informações do cliente e dizer automaticamente o score de crédito dele: Ruim, Ok, Bom
#
# Arquivos da aula: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
# passo 0 - Entender o desafio da empresa que você vai resolver
# passo 1 - Importar base de dados
# passo 2 - Preparar base de dados para a inteligência artificial
# passo 3 - Criar um modelo de inteligência artificial-> Prever o score Bom, Ruim ou Médio
# passo 4 - Escolher qual o melhor modelo de IA 
# passo 5 - Usar a IA para definir o score de crédito
# !pip install pandas numpy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Importar Base de Dados
import sklearn
import pandas as pd
tabela = pd.read_csv("clientes.csv")
display(tabela)
# Out:
# C:\Users\TecnoSys\AppData\Local\Temp\ipykernel_5948\2247965832.py:4: DtypeWarning: Columns (0,1,2,4,5,6,7,8,9,10,11,13,14,15,16,18,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela = pd.read_csv("clientes.csv")
#                  x Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0       id_cliente        mes      idade  profissao  salario_anual
# 1             3392          1         23  cientista       19114.12
# 2             3392          2         23  cientista       19114.12
# 3             3392          3         23  cientista       19114.12
# 4             3392          4         23  cientista       19114.12
# ...            ...        ...        ...        ...            ...
# 99998        37932          4         25   mecanico       39628.99
# 99999        37932          5         25   mecanico       39628.99
# 100000       37932          6         25   mecanico       39628.99
# ...

# %%
# passo 2 - Preparar base de dados para a inteligência artificial
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   x            100003 non-null  object
#  1   Unnamed: 1   100001 non-null  object
#  2   Unnamed: 2   100001 non-null  object
#  3   Unnamed: 3   100001 non-null  object
#  4   Unnamed: 4   100001 non-null  object
#  5   Unnamed: 5   100001 non-null  object
#  6   Unnamed: 6   100001 non-null  object
#  7   Unnamed: 7   100001 non-null  object
#  8   Unnamed: 8   100001 non-null  object
#  9   Unnamed: 9   100001 non-null  object
#  10  Unnamed: 10  100001 non-null  object
#  11  Unnamed: 11  100001 non-null  object
#  12  Unnamed: 12  100001 non-null  object
#  13  Unnamed: 13  100001 non-null  object
#  14  Unnamed: 14  100001 non-null  object
#  15  Unnamed: 15  100001 non-null  object
#  16  Unnamed: 16  100001 non-null  object
#  17  Unnamed: 17  100001 non-null  object
# ...

# %%
#TRATAR AS COLUNAS
# profissão
    # engenheiro - 1
    # advogado - 2
    # cientista - 3
    # ator - 4
    # mecanico - 5
# mix credito
# comportamento_pagamento

from sklearn.preprocessing import LabelEncoder
tabela = pd.read_csv("clientes.csv")

codificador = LabelEncoder()

tabela["profissao"] = codificador.fit_transform(tabela["profissao"])

tabela["mix_credito"] = codificador.fit_transform(tabela["mix_credito"])

tabela ["comportamento_pagamento"] = codificador.fit_transform(tabela["comportamento_pagamento"])
display(tabela.info())
# Out:
# C:\Users\TecnoSys\AppData\Local\Temp\ipykernel_5948\610362204.py:12: DtypeWarning: Columns (0,1,2,4,5,6,7,8,9,10,11,13,14,15,16,18,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela = pd.read_csv("clientes.csv")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# Y = Quem você quer prever o Score de crédito
y = tabela["score_credito"]

# X = Colunas que você vai usar para prever o score de crédito
x= tabela.drop(columns=["id_cliente", "score_credito"])

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score_credito'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Passo 3: Criar o modelo de IA-> Prever o Score de crédito

# Árvore de decisão-> RandomForrest
# KNN-> Vizinhos próxios
# Importar a IA
tabela = pd.read_csv("clientes.csv")
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Criar a IA
modelo_arvoredecisão = RandomForestClassifier()
modelo_knn = KNeighborsClassifier()

# Treinar a IA
modelo_arvoredecisão.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
# Out:
# C:\Users\TecnoSys\AppData\Local\Temp\ipykernel_5948\3341015633.py:6: DtypeWarning: Columns (0,1,2,4,5,6,7,8,9,10,11,13,14,15,16,18,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela = pd.read_csv("clientes.csv")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      13 modelo_knn = KNeighborsClassifier()
#      15 # Treinar a IA
# ---> 16 modelo_arvoredecisão.fit(x_treino, y_treino)
#      17 modelo_knn.fit(x_treino, y_treino)
#
# NameError: name 'x_treino' is not defined
